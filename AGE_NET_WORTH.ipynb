# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohitha-M-Raghu/PROJECTS/blob/main/AGE_NET_WORTH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A linear regression program to find the salary depending upon the age of a person.
# First import the necessary libraries.
# NUMPY - NUMPY arrays
# MATplot - visualisation
# seaborn - to plot the graph
# random to generate random values

# %%
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# Training function
# import Linear Regression from scikit lib

# %%
def studentReg(ages_train, net_worths_train):
  from sklearn.linear_model import LinearRegression
  reg = LinearRegression().fit(ages_train, net_worths_train)
  return reg

# %% [markdown]
# generate random numbers
# create empty list to get random number.Random generates 250 random ages btw 18 and 75. Seed is to generate the same random numbers.
# convert them into array and reshape them into 2D. (list -> array and reshaped it into 2D)

# %%
numpy.random.seed(42)

ages = []

for ii in range(250):
  ages.append(random.randint(18,75))

net_worths = [ii * 6.25 +numpy.random.normal(scale = 40)for ii in ages]

ages = numpy.reshape(numpy.array(ages),(len(ages),1))
net_worths = numpy.reshape(numpy.array(net_worths),(len(net_worths),1))

from sklearn.model_selection import train_test_split

ages_train, ages_test, net_worths_train, net_worths_test = train_test_split(ages, net_worths)

reg1 = studentReg(ages_train, net_worths_train)

print("coefficient", reg1.coef_)
print("Intercept",reg1.intercept_)
print("Training data",reg1.score(ages_train,net_worths_train))
print("Testing data",reg1.score(ages_test, net_worths_test))
# Out:
# coefficient [[6.46887398]]
# Intercept [-13.64199099]
# Training data 0.8772076174519035
# Testing data 0.8988592726509046

# %% [markdown]
# Create a graph using training data

# %%
plt.figure(figsize = (12, 10))
sns.regplot(x=ages_train, y = net_worths_train, scatter = True, color = "b", marker = "*" )
plt.xlabel("Age Train")
plt.ylabel("Net Worth Train")
plt.title("Regression plot")
# Out:
# Text(0.5, 1.0, 'Regression plot')

# %% [markdown]
# visuaising the pretidcted on test data set

# %%
plt.figure(figsize = (12,10))
plt.scatter(ages_train,net_worths_train,color = "b",label = "train data")
plt.scatter(ages_test, net_worths_test, color = "r", label = "test data")
plt.plot(ages_test, reg1.predict(ages_test))

plt.xlabel("Ages")
plt.ylabel("Net Worth")
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# *  blue - training data
# *   red - test data
# prediction line
